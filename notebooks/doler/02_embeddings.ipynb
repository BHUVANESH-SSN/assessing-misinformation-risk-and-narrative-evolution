# %% [markdown]
# # 02 Embeddings
#
# ## Load Embedding Model and Tokenizer
# - Load sentence embedding model
# - Configure device
# - Verify readiness
#
# ## Generate and Persist Embeddings
# - Batch texts
# - Compute embeddings
# - Save vectors with identifiers
#
# ## Validate Embedding Shapes and Similarities
# - Check dimensions
# - Compute sample cosine similarities
# - Sanity-check nearest neighbors

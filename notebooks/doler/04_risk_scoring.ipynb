# %% [markdown]
# # 04 Risk Scoring
#
# ## Define Risk Features
# - Engineer features from text, metadata, and clusters
#
# ## Train Risk Scoring Model
# - Train classifier/regressor
# - Tune hyperparameters
# - Save trained model
#
# ## Score and Calibrate Outputs
# - Generate risk scores
# - Apply calibration if needed
# - Save scored outputs

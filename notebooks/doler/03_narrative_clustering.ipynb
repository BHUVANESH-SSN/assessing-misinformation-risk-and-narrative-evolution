# %% [markdown]
# # 03 Narrative Clustering
#
# ## Dimensionality Reduction for Clustering
# - Apply PCA or UMAP
# - Store reduced vectors
#
# ## Cluster Narratives
# - Run clustering (KMeans or HDBSCAN)
# - Pick hyperparameters
# - Persist cluster labels
#
# ## Label and Inspect Clusters
# - Summarize clusters with top terms
# - Sample narratives
# - Optional manual labels

# %% [markdown]
# # 03 Embeddings

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# %%
df = pd.read_csv("../data/processed/clean_text_data.csv")
df.head()
# Out:
#                                                 text  \
# 0  Vaccines cause serious side effects according ...
# 1         5G towers are spreading harmful radiation.
# 2   Government confirms vaccine safety after trials.
# 3  Social media claims about microchips in vaccin...
#
#                                           clean_text  word_count
# 0    vaccine cause serious side effect accord report           7
# 1                   g tower spread harmful radiation           5
# 2            government confirm vaccine safety trial           5
# 3  social medium claim microchip vaccine spread r...           7

# %%
assert "clean_text" in df.columns

# %%
texts = df["clean_text"].tolist()
len(texts)
# Out:
# 4

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings = model.encode(
    texts,
    batch_size=32,
    show_progress_bar=True,
    convert_to_numpy=True
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
embeddings.shape
# Out:
# (4, 384)

# %%
df["embedding"] = embeddings.tolist()
df.head()
# Out:
#                                                 text  \
# 0  Vaccines cause serious side effects according ...
# 1         5G towers are spreading harmful radiation.
# 2   Government confirms vaccine safety after trials.
# 3  Social media claims about microchips in vaccin...
#
#                                           clean_text  word_count  \
# 0    vaccine cause serious side effect accord report           7
# 1                   g tower spread harmful radiation           5
# 2            government confirm vaccine safety trial           5
# 3  social medium claim microchip vaccine spread r...           7
#
#                                            embedding
# 0  [0.03118378110229969, 0.0501067191362381, 0.00...
# 1  [-0.006589553784579039, 0.04794309660792351, 0...
# 2  [-0.02094881422817707, 0.03403022512793541, -0...
# 3  [-0.03794294223189354, 0.044644929468631744, 0...

# %%
np.save("../data/embeddings/text_embeddings.npy", embeddings)

# %%
print("Sample embedding vector length:", len(embeddings[0]))
print("First 5 values:", embeddings[0][:5])
# Out:
# Sample embedding vector length: 384
# First 5 values: [0.03118378 0.05010672 0.00583152 0.03123833 0.03458027]
